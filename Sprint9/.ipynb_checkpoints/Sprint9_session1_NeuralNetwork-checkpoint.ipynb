# %% [markdown]
# 計算が止まらなくなり、最初に作っていたものは全部消してしまった。代わりに３人の方の模写とコードリーディングをやった。主にはスーパーエンジニアと、佐藤さんのが短いのでどちらかを理解出来れば良さそう。何をやっているかの理解は少し前には進んだので残しておいて、復習をいずれする。
# リーダブルコード的にはコメントを残すのもナンセンスなようなので、佐藤さんの模写はノーコメントでやった。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 評価指標
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

x_train = x_train.astype(np.float)
x_test = x_test.astype(np.float)
x_train /= 255
x_test /= 255

y_train_one_hot = (y_train.reshape(-1, 1) == np.arange(10)).astype(np.float64)
y_test_one_hot = (y_test.reshape(-1, 1) == np.arange(10)).astype(np.float64)

# %%
def split_data(data, permutation, val_size_rate=0.2):
    data = data[permutation]
    val_size = int(len(data) * val_size_rate)
    val = data[:val_size]
    train = data[val_size:]
    return train, val

permutation = np.random.permutation(np.arange(len(x_train)))
x_train, x_val = split_data(x_train, permutation)
y_train, y_val = split_data(y_train, permutation)

# %% [markdown]
# # スーパーエンジニアの方の模写

# %%
def logsumexp(x):
    """Calculates log(sum(exp(x))).
    """
    xmax = x.max(axis=1, keepdims=True)
    return np.log(np.exp(x - xmax).sum(axis=1, keepdims=True)) + xmax


class ScratchSimpleNeuralNetrowkClassifier:
    """MNISTを学習する3層ニューラルネットワーク

    Parameter:
    ----------
    seed (int): シード値
    verbose (bool): ログ出力するかどうかのflag
    """

    n1, n2, n3, n4 = 784, 400, 200, 10

    def __init__(self, seed=0, verbose = True):
         # Problem 1. (initialization)
        self.verbose = verbose
        sigma = 0.01
        np.random.seed(seed)
        self.w1 = np.random.normal(0, sigma, (self.n1, self.n2))  # self.w1.shape == (784, 400)
        self.b1 = np.random.normal(0, sigma, self.n2)  # self.b1.shape == (400,)
        self.w2 = np.random.normal(0, sigma, (self.n2, self.n3))  # self.w2.shape == (400, 200)
        self.b2 = np.random.normal(0, sigma, self.n3)  # self.b2.shape == (200,)
        self.w3 = np.random.normal(0, sigma, (self.n3, self.n4))  # self.w3.shape == (200, 10)
        self.b3 = np.random.normal(0, sigma, self.n4)  # self.b3.shape == (10,)

    def forward(self, x):
        """forward propergation

        Parameter:
        ----------
        x (ndarra): 平滑化された画像データ (batch_size, 784) float64

        Returns:
        --------
        log_z3: 各画像データとラベルの組についての確率の対数 (batch_size, 10) float64
        """
        # Problem 2. (forward propagation)
        batch_size = x.shape[0]
        self.x = x.reshape(batch_size, 784)  # self.x.shape == (batch_size, 784)
        self.a1 = self.x.dot(self.w1) + self.b1  # self.a1.shape == (batch_size, 400)
        self.z1 = np.tanh(self.a1)  # self.z1.shape == (batch_size, 400)
        self.a2 = self.z1.dot(self.w2) + self.b2  # self.a2.shape == (batch_size, 200)
        self.z2 = np.tanh(self.a2)  # self.z2.shape == (batch_size, 200)
        self.a3 = self.z2.dot(self.w3) + self.b3  # self.a3.shape == (batch_size, 10)
        # 以下の式は a3 の値が大きい時に overflow するので避ける
        # self.z3 = np.exp(self.a3) / np.exp(self.a3).sum(axis=1, keepdims=True)
        log_z3 = self.a3 - logsumexp(self.a3)
        self.z3 = np.exp(log_z3)
        return log_z3

    def forward_and_loss(self, x, y):
        """forward propergation + loss

        Parameter:
        ----------
        x (ndarray): 平滑化された画像データ (batch_size, 784) float64
        y (ndarray): 正解ラベル (batch_size,) int64

        Returns:
        --------
        loss (float64): loss値
        correct (int64): 正答数
        """
        # Problem 3. (cross entropy)
        self.y = y.reshape(-1, 1) == np.arange(10)  # one-hot 表現に変換する
        log_z3 = self.forward(x)
        loss = -(self.y * log_z3).mean(axis=0).sum()
        correct = (self.z3.argmax(axis=1) == y).sum()
        return loss, correct
        
    def backprop(self, alpha=0.01):
        # Problem 4. (back propagation)
        batch_size = self.x.shape[0]
        ga3 = (self.z3 - self.y) / batch_size
        self.b3 -= alpha * ga3.sum(axis=0)
        self.w3 -= alpha * self.z2.T.dot(ga3)
        gz2 = ga3.dot(self.w3.T)
        ga2 = gz2 * (1 - self.z2 ** 2)
        self.b2 -= alpha * ga2.sum(axis=0)
        self.w2 -= alpha * self.z1.T.dot(ga2)
        gz1 = ga2.dot(self.w2.T)
        ga1 = gz1 * (1 - self.z1 ** 2)
        self.b1 -= alpha * ga1.sum(axis=0)
        self.w1 -= alpha * self.x.T.dot(ga1)

    def fit(self, x_train, y_train, x_val, y_val, batch_size=20):

        n_epochs = 20
        n_step_iteration_report = 500
        plot_data = []

        # Problem 6.
        for epoch in range(n_epochs):
            sum_of_loss = 0
            for i, (x, y) in enumerate(get_minibatches(x_train, y_train, batch_size)):
                self.y = y.reshape(-1, 1) == np.arange(10)
                loss, correct = self.forward_and_loss(x, y)
                self.backprop()
               
                # ログ出力
                sum_of_loss += loss
                if self.verbose and (i + 1) % n_step_iteration_report == 0:
                    train_loss = sum_of_loss / n_step_iteration_report
                    val_loss, correct = self.forward_and_loss(x_val, y_val)
                    print(f'epoch: {epoch+1}, iteration: {i+1}, train_loss: {train_loss:.3}, val_loss: {val_loss:.3}, accuracty: {correct / len(y_val):.3}')
                    sum_of_loss = 0

                    iters_per_epoch = len(x_train) / batch_size
                    plot_data.append((epoch + (i + 1) / iters_per_epoch, train_loss, val_loss))

        #  学習曲線のプロット
        if self.verbose:
            epochs, train_loss, val_loss = zip(*plot_data)
            plt.plot(epochs, train_loss, color='r', label='train_loss')
            plt.plot(epochs, val_loss, color='b', label='val_loss')
            plt.xlabel('epoch')
            plt.ylabel('loss')
            plt.show()

    def predict(self, X):
        # Problem 5.
        return self.forward(X).argmax(axis=1)

# %%
def get_minibatches(x, y, batch_size):
    """Returns a generator emits mini-batches.
    """
    size = x.shape[0]
    n_batches = size // batch_size
    shuffle_index = np.random.permutation(np.arange(size))
    new_size = batch_size * n_batches
    x_batches = np.split(x[shuffle_index][:new_size], n_batches)
    y_batches = np.split(y[shuffle_index][:new_size], n_batches)
    return zip(x_batches, y_batches)

# %%
model = ScratchSimpleNeuralNetrowkClassifier()
model.fit(x_train, y_train, x_val, y_val)
# Out:
# epoch: 1, iteration: 500, train_loss: 2.29, val_loss: 2.28, accuracty: 0.392
# epoch: 1, iteration: 1000, train_loss: 2.22, val_loss: 2.07, accuracty: 0.339
# epoch: 1, iteration: 1500, train_loss: 1.67, val_loss: 1.27, accuracty: 0.609
# epoch: 1, iteration: 2000, train_loss: 1.02, val_loss: 0.819, accuracty: 0.747
# epoch: 2, iteration: 500, train_loss: 0.614, val_loss: 0.573, accuracty: 0.836
# epoch: 2, iteration: 1000, train_loss: 0.539, val_loss: 0.508, accuracty: 0.853
# epoch: 2, iteration: 1500, train_loss: 0.479, val_loss: 0.466, accuracty: 0.867
# epoch: 2, iteration: 2000, train_loss: 0.455, val_loss: 0.433, accuracty: 0.876
# epoch: 3, iteration: 500, train_loss: 0.391, val_loss: 0.398, accuracty: 0.887
# epoch: 3, iteration: 1000, train_loss: 0.369, val_loss: 0.382, accuracty: 0.891
# epoch: 3, iteration: 1500, train_loss: 0.388, val_loss: 0.374, accuracty: 0.893
# epoch: 3, iteration: 2000, train_loss: 0.37, val_loss: 0.36, accuracty: 0.895
# epoch: 4, iteration: 500, train_loss: 0.343, val_loss: 0.347, accuracty: 0.899
# epoch: 4, iteration: 1000, train_loss: 0.329, val_loss: 0.342, accuracty: 0.902
# epoch: 4, iteration: 1500, train_loss: 0.328, val_loss: 0.338, accuracty: 0.901
# epoch: 4, iteration: 2000, train_loss: 0.333, val_loss: 0.334, accuracty: 0.904
# epoch: 5, iteration: 500, train_loss: 0.323, val_loss: 0.321, accuracty: 0.909
# epoch: 5, iteration: 1000, train_loss: 0.308, val_loss: 0.315, accuracty: 0.909
# epoch: 5, iteration: 1500, train_loss: 0.295, val_loss: 0.313, accuracty: 0.913
# epoch: 5, iteration: 2000, train_loss: 0.3, val_loss: 0.309, accuracty: 0.912
# epoch: 6, iteration: 500, train_loss: 0.289, val_loss: 0.298, accuracty: 0.914
# epoch: 6, iteration: 1000, train_loss: 0.293, val_loss: 0.294, accuracty: 0.915
# epoch: 6, iteration: 1500, train_loss: 0.275, val_loss: 0.293, accuracty: 0.915
# epoch: 6, iteration: 2000, train_loss: 0.273, val_loss: 0.286, accuracty: 0.92
# epoch: 7, iteration: 500, train_loss: 0.268, val_loss: 0.278, accuracty: 0.921
# epoch: 7, iteration: 1000, train_loss: 0.262, val_loss: 0.273, accuracty: 0.923
# epoch: 7, iteration: 1500, train_loss: 0.257, val_loss: 0.271, accuracty: 0.923
# epoch: 7, iteration: 2000, train_loss: 0.256, val_loss: 0.269, accuracty: 0.923
# epoch: 8, iteration: 500, train_loss: 0.244, val_loss: 0.261, accuracty: 0.924
# epoch: 8, iteration: 1000, train_loss: 0.251, val_loss: 0.258, accuracty: 0.927
# epoch: 8, iteration: 1500, train_loss: 0.229, val_loss: 0.257, accuracty: 0.928
# epoch: 8, iteration: 2000, train_loss: 0.242, val_loss: 0.253, accuracty: 0.928
# epoch: 9, iteration: 500, train_loss: 0.236, val_loss: 0.248, accuracty: 0.928
# epoch: 9, iteration: 1000, train_loss: 0.222, val_loss: 0.241, accuracty: 0.93
# epoch: 9, iteration: 1500, train_loss: 0.23, val_loss: 0.239, accuracty: 0.932
# epoch: 9, iteration: 2000, train_loss: 0.221, val_loss: 0.236, accuracty: 0.933
# epoch: 10, iteration: 500, train_loss: 0.208, val_loss: 0.229, accuracty: 0.935
# epoch: 10, iteration: 1000, train_loss: 0.217, val_loss: 0.228, accuracty: 0.934
# epoch: 10, iteration: 1500, train_loss: 0.209, val_loss: 0.226, accuracty: 0.936
# epoch: 10, iteration: 2000, train_loss: 0.215, val_loss: 0.224, accuracty: 0.935
# epoch: 11, iteration: 500, train_loss: 0.196, val_loss: 0.218, accuracty: 0.938
# epoch: 11, iteration: 1000, train_loss: 0.2, val_loss: 0.214, accuracty: 0.938
# epoch: 11, iteration: 1500, train_loss: 0.187, val_loss: 0.213, accuracty: 0.938
# epoch: 11, iteration: 2000, train_loss: 0.198, val_loss: 0.21, accuracty: 0.941
# epoch: 12, iteration: 500, train_loss: 0.187, val_loss: 0.205, accuracty: 0.942
# epoch: 12, iteration: 1000, train_loss: 0.19, val_loss: 0.204, accuracty: 0.94
# epoch: 12, iteration: 1500, train_loss: 0.186, val_loss: 0.199, accuracty: 0.944
# epoch: 12, iteration: 2000, train_loss: 0.176, val_loss: 0.199, accuracty: 0.943
# epoch: 13, iteration: 500, train_loss: 0.173, val_loss: 0.192, accuracty: 0.944
# epoch: 13, iteration: 1000, train_loss: 0.172, val_loss: 0.193, accuracty: 0.944
# epoch: 13, iteration: 1500, train_loss: 0.166, val_loss: 0.196, accuracty: 0.944
# epoch: 13, iteration: 2000, train_loss: 0.171, val_loss: 0.189, accuracty: 0.947
# epoch: 14, iteration: 500, train_loss: 0.161, val_loss: 0.184, accuracty: 0.947
# epoch: 14, iteration: 1000, train_loss: 0.165, val_loss: 0.183, accuracty: 0.947
# epoch: 14, iteration: 1500, train_loss: 0.16, val_loss: 0.182, accuracty: 0.949
# epoch: 14, iteration: 2000, train_loss: 0.161, val_loss: 0.178, accuracty: 0.948
# epoch: 15, iteration: 500, train_loss: 0.151, val_loss: 0.175, accuracty: 0.951
# epoch: 15, iteration: 1000, train_loss: 0.146, val_loss: 0.178, accuracty: 0.949
# epoch: 15, iteration: 1500, train_loss: 0.146, val_loss: 0.171, accuracty: 0.952
# epoch: 15, iteration: 2000, train_loss: 0.152, val_loss: 0.17, accuracty: 0.952
# epoch: 16, iteration: 500, train_loss: 0.142, val_loss: 0.166, accuracty: 0.952
# epoch: 16, iteration: 1000, train_loss: 0.131, val_loss: 0.163, accuracty: 0.953
# epoch: 16, iteration: 1500, train_loss: 0.139, val_loss: 0.164, accuracty: 0.954
# epoch: 16, iteration: 2000, train_loss: 0.147, val_loss: 0.158, accuracty: 0.955
# epoch: 17, iteration: 500, train_loss: 0.134, val_loss: 0.157, accuracty: 0.954
# epoch: 17, iteration: 1000, train_loss: 0.136, val_loss: 0.155, accuracty: 0.954
# epoch: 17, iteration: 1500, train_loss: 0.135, val_loss: 0.157, accuracty: 0.955
# epoch: 17, iteration: 2000, train_loss: 0.128, val_loss: 0.153, accuracty: 0.957
# epoch: 18, iteration: 500, train_loss: 0.121, val_loss: 0.152, accuracty: 0.957
# epoch: 18, iteration: 1000, train_loss: 0.123, val_loss: 0.15, accuracty: 0.957
# epoch: 18, iteration: 1500, train_loss: 0.121, val_loss: 0.149, accuracty: 0.957
# epoch: 18, iteration: 2000, train_loss: 0.131, val_loss: 0.149, accuracty: 0.956
# epoch: 19, iteration: 500, train_loss: 0.118, val_loss: 0.145, accuracty: 0.959
# epoch: 19, iteration: 1000, train_loss: 0.11, val_loss: 0.145, accuracty: 0.958
# epoch: 19, iteration: 1500, train_loss: 0.121, val_loss: 0.143, accuracty: 0.959
# epoch: 19, iteration: 2000, train_loss: 0.117, val_loss: 0.142, accuracty: 0.958
# epoch: 20, iteration: 500, train_loss: 0.109, val_loss: 0.139, accuracty: 0.96
# epoch: 20, iteration: 1000, train_loss: 0.12, val_loss: 0.14, accuracty: 0.96
# epoch: 20, iteration: 1500, train_loss: 0.113, val_loss: 0.137, accuracty: 0.96
# epoch: 20, iteration: 2000, train_loss: 0.107, val_loss: 0.136, accuracty: 0.962

# %%
# Problem 8.
h, w = 6, 6
num = h * w
y_pred = model.predict(x_test)
falses = (y_pred != y_test).nonzero()[0][:num]
num = len(falses)
fig = plt.figure(figsize=(h, w))
fig.subplots_adjust(left=0, right=0.8,  bottom=0, top=0.8, hspace=1, wspace=0.5)
for i in range(num):
    ax = fig.add_subplot(h, w, i + 1, xticks=[], yticks=[])
    ax.set_title("{} / {}".format(y_pred[falses[i]], y_test[falses[i]]))
    ax.imshow(x_test[falses[i]].reshape(28, 28), cmap='gray')

# %% [markdown]
# # 前期の増田さんのコード

# %%
# ミニバッチ処理のクラス
class GetMiniBatch:
    """
    ミニバッチを取得するイテレータ

    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      訓練データ
    y : 次の形のndarray, shape (n_samples, 1)
      正解値
    batch_size : int
      バッチサイズ
    seed : int
      NumPyの乱数のシード
    """
    def __init__(self, X, y, batch_size = 20, seed=None):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self._X = X[shuffle_index]
        self._y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
    def __len__(self):
        return self._stop
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self._X[p0:p1], self._y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self._X[p0:p1], self._y[p0:p1]

# %%
# スクラッチ　ニューラルネットワーク
class ScratchSimpleNeuralNetrowkClassifier():
    """
    シンプルな三層ニューラルネットワーク分類器
    Parameters
    ----------

    Attributes
    ----------
    """
    def __init__(self, n_epoch=50, n_features=784, n_nodes1=400, n_nodes2=200, 
                 n_output=10, sigma=0.01, n_batch=20, 
                 activate_function_key='tanh', lr = 0.01, verbose = False):
        
        self.n_epoch = n_epoch
        self.n_features = n_features
        self.n_nodes1 = n_nodes1
        self.n_nodes2 = n_nodes2
        self.n_output = n_output
        self.sigma = sigma
        self.n_batch = n_batch
        self.activate_function_key = activate_function_key
        self.lr = lr
        self.verbose = verbose
        
    def initial_weight(self):
        self.W1 = self.sigma * np.random.randn(self.n_features, self.n_nodes1)
        self.b1 = np.zeros(self.n_nodes1)
        self.W2 = self.sigma * np.random.randn(self.n_nodes1, self.n_nodes2)
        self.b2 = np.zeros(self.n_nodes2)
        self.W3 = self.sigma * np.random.randn(self.n_nodes2, self.n_output)
        self.b3 = np.zeros(self.n_output)
        
    def activation_function(self,X):
        if self.activate_function_key == 'sigmoid':
            return 1/(1+np.exp(-X))
        
        elif self.activate_function_key == 'tanh':
            return np.tanh(X)
    
    def softmax(self,X):
        
        return np.exp(X-np.max(X))/np.sum(np.exp(X-np.max(X)),axis=1,keepdims=True)
    
    def loss_function(self,y,yt):
        delta = 1e-7
        return -np.mean(yt*np.log(y+delta))
    
    def gradient_descent(self,X,y,yt):
        
            # 3層目
            delta_a3 = (y-yt)/self.n_batch
            delta_b3 = np.sum(delta_a3,axis=0)
            delta_W3 = np.dot(self.z2.T,delta_a3)
            delta_z2 = np.dot(delta_a3,self.W3.T)
        
            self.W3 -= self.lr*delta_W3
            self.b3 -= self.lr*delta_b3
        
            # 2層目
            if self.activate_function_key == 'sigmoid':
                delta_a2 = delta_z2*(1-self.activation_function(self.z2))*self.activation_function(self.z2)
            
            elif self.activate_function_key == 'tanh':
                delta_a2 = delta_z2*(1-np.tanh(self.z2)**2)
            
            delta_b2 = np.sum(delta_a2,axis=0)
            delta_W2 = np.dot(self.z1.T,delta_a2)
            delta_z1 = np.dot(delta_a2,self.W2.T)
        
            self.W2 -= self.lr*delta_W2
            self.b2 -= self.lr*delta_b2
        
            # 1層目
            if self.activate_function_key == 'sigmoid':
                delta_a1 = delta_z1*(1-self.activation_function(self.z1))*self.activation_function(self.z1)
            
            elif self.activate_function_key == 'tanh':
                delta_a1 = delta_z1*(1-np.tanh(self.z1)**2)
                
            delta_b1 = np.sum(delta_a1,axis=0)
            delta_W1 = np.dot(X.T,delta_a1)
        
            self.W1 -= self.lr*delta_W1
            self.b1 -= self.lr*delta_b1
                
    def fit(self, X, y, X_val=False, y_val=False):
        """
        ニューラルネットワーク分類器を学習する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            訓練データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            訓練データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証データの正解値
        """
        # 重みの初期化
        self.initial_weight()
        
        # エポックごとのloss_functionを記録するリスト
        self.log_loss = []
        self.log_loss_val = []
        
        # エポックごとのTrainデータの推定を評価：Accuracy
        self.log_acc = []
        self.log_acc_val = []
        
        for epoch in range(self.n_epoch):
            # ミニバッチ処理
            get_mini_batch = GetMiniBatch(X, y, batch_size=self.n_batch)
            
            self.loss = 0
            self.true_y = np.array([])
            self.pred_y = np.array([])
            
            for mini_X_train, mini_y_train in get_mini_batch:
            
                # 1層目
                self.z1 = self.activation_function(np.dot(mini_X_train,self.W1) + self.b1)
            
                # 2層目
                self.z2 = self.activation_function(np.dot(self.z1,self.W2) + self.b2)
            
                # 3層目（ソフトマックス関数）
                yhat = self.softmax(np.dot(self.z2,self.W3) + self.b3)
                
                # バックプロパゲーション（確率的勾配降下法）
                self.gradient_descent(mini_X_train,yhat,mini_y_train)
                
                # ミニバッチデータの正解値、推定値を記録
                self.true_y = np.concatenate([self.true_y,np.argmax(mini_y_train,axis=1)])
                self.pred_y = np.concatenate([self.pred_y,np.argmax(yhat,axis=1)])
                
                # 損失関数
                self.loss += self.loss_function(yhat,mini_y_train)
            
            # epochごとに損失関数を記録
            self.log_loss.append(self.loss/len(get_mini_batch))
            
            # Accuracy
            acc = accuracy_score(self.true_y, self.pred_y)
            self.log_acc.append(acc)
            
            # Valデータが入力されたら計算
            if (type(X_val) != bool):
                # 1層目
                self.z1_val = self.activation_function(np.dot(X_val,self.W1) + self.b1)
            
                # 2層目
                self.z2_val = self.activation_function(np.dot(self.z1_val,self.W2) + self.b2)
            
                # 3層目（ソフトマックス関数）
                yhat_val = self.softmax(np.dot(self.z2_val,self.W3) + self.b3)
                
                # 損失関数
                self.loss_val = self.loss_function(yhat_val,y_val)
                self.log_loss_val.append(self.loss_val)
                
                # Accuracy
                
                acc_val = accuracy_score(np.argmax(y_val,axis=1), np.argmax(yhat_val,axis=1))
                self.log_acc_val.append(acc_val)
            
            #verboseをTrueにした際は学習過程などを出力する
            if self.verbose:
                print('epoch:{:>3} loss:{:>8,.3f} acc:{:>5,.3f}'.format(epoch,self.loss/self.n_batch,acc))
            
    def predict(self, X):
        """
        ニューラルネットワーク分類器を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            推定結果
        """
        # 1層目
        self.pred_z1 = self.activation_function(np.dot(X,self.W1) + self.b1)
            
        # 2層目
        self.pred_z2 = self.activation_function(np.dot(self.pred_z1,self.W2) + self.b2)
        
        return np.argmax(np.dot(self.pred_z2,self.W3) + self.b3, axis=1)

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

x_train = x_train.astype(np.float)
x_test = x_test.astype(np.float)
x_train /= 255
x_test /= 255

x_train,x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2)

# %%
y_train_one_hot = (y_train.reshape(-1, 1) == np.arange(10)).astype(np.float64)
y_val_one_hot = (y_val.reshape(-1, 1) == np.arange(10)).astype(np.float64)

# %%
clf = ScratchSimpleNeuralNetrowkClassifier(n_epoch=30, n_features=784,
                                           n_nodes1=400, n_nodes2=200, n_output=10,
                                           sigma=0.01, n_batch=100,
                                           activate_function_key='tanh',
                                           lr = 0.01, verbose = True)

clf.fit(x_train,y_train_one_hot,x_val,y_val_one_hot)
y_pred = clf.predict(x_val)
# Out:
# epoch:  0 loss:   1.102 acc:0.158
# epoch:  1 loss:   1.077 acc:0.345
# epoch:  2 loss:   0.839 acc:0.430
# epoch:  3 loss:   0.509 acc:0.644
# epoch:  4 loss:   0.366 acc:0.778
# epoch:  5 loss:   0.299 acc:0.817
# epoch:  6 loss:   0.258 acc:0.842
# epoch:  7 loss:   0.232 acc:0.859
# epoch:  8 loss:   0.214 acc:0.871
# epoch:  9 loss:   0.201 acc:0.880
# epoch: 10 loss:   0.191 acc:0.887
# epoch: 11 loss:   0.183 acc:0.891
# epoch: 12 loss:   0.177 acc:0.895
# epoch: 13 loss:   0.172 acc:0.898
# epoch: 14 loss:   0.168 acc:0.900
# epoch: 15 loss:   0.164 acc:0.902
# epoch: 16 loss:   0.161 acc:0.904
# epoch: 17 loss:   0.158 acc:0.907
# epoch: 18 loss:   0.155 acc:0.908
# epoch: 19 loss:   0.152 acc:0.910
# epoch: 20 loss:   0.150 acc:0.911
# epoch: 21 loss:   0.148 acc:0.912
# epoch: 22 loss:   0.145 acc:0.914
# epoch: 23 loss:   0.143 acc:0.915
# epoch: 24 loss:   0.141 acc:0.916
# epoch: 25 loss:   0.139 acc:0.918
# epoch: 26 loss:   0.137 acc:0.919
# epoch: 27 loss:   0.135 acc:0.920
# epoch: 28 loss:   0.133 acc:0.921
# epoch: 29 loss:   0.131 acc:0.922

# %%
# epochごとの損失関数の可視化
fig = plt.subplots(figsize=(12,8))
plt.rcParams["font.size"] = 20

plt.plot(clf.log_loss,'rs--')
plt.plot(clf.log_loss_val,'bo--');

# %%
# epochごとの正解率の可視化
fig = plt.subplots(figsize=(12,8))
plt.rcParams["font.size"] = 20

plt.plot(clf.log_acc,'rs--')
plt.plot(clf.log_acc_val,'bo--');

# %%
num = 5 # いくつ表示するか
print('推定結果/正解')

true_false = y_pred==y_val
false_list = np.where(true_false==False)[0].astype(np.int)
if false_list.shape[0] < num:
    num = false_list.shape[0]
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left=0, right=0.8,  bottom=0, top=0.8, hspace=1, wspace=0.5)
for i in range(num):
    ax = fig.add_subplot(6, 6, i + 1, xticks=[], yticks=[])
    ax.set_title("{} / {}".format(y_pred[false_list[i]],y_val[false_list[i]]))
    ax.imshow(x_val.reshape(-1,28,28)[false_list[i]], cmap='gray')
# Out:
# 推定結果/正解

# %% [markdown]
# # 今期の佐藤さんのコード

# %%
# ミニバッチ処理
class GetMiniBatch:
    """
    ミニバッチを取得するイテレータ
    Parameters
    ----------
    X : 次の形のndarray, shape (n_samples, n_features)
      訓練データ
    y : 次の形のndarray, shape (n_samples, 1)
      正解値
    batch_size : int
      バッチサイズ
    seed : int
      NumPyの乱数のシード
    """
    def __init__(self, X, y, batch_size = 20, seed=0):
        self.batch_size = batch_size
        np.random.seed(seed)
        shuffle_index = np.random.permutation(np.arange(X.shape[0]))
        self._X = X[shuffle_index]
        self._y = y[shuffle_index]
        self._stop = np.ceil(X.shape[0]/self.batch_size).astype(np.int)
    def __len__(self):
        return self._stop
    def __getitem__(self,item):
        p0 = item*self.batch_size
        p1 = item*self.batch_size + self.batch_size
        return self._X[p0:p1], self._y[p0:p1]        
    def __iter__(self):
        self._counter = 0
        return self
    def __next__(self):
        if self._counter >= self._stop:
            raise StopIteration()
        p0 = self._counter*self.batch_size
        p1 = self._counter*self.batch_size + self.batch_size
        self._counter += 1
        return self._X[p0:p1], self._y[p0:p1]

# %%
class ScratchSimpleNeuralNetworkClassifier():
    
    SIGMOID, TAN_H = 0, 1
    
    def __init__(self, alpha =0.01, n_epochs =30, activation_function_flg=1, sigma =0.01, verbose=True):
        self.alpha = alpha
        self.n_epochs = n_epochs
        self.verbose = verbose
        self.activation_function_flg = activation_function_flg
        self.sigma = sigma
        
        self.n_nodes1, self.n_nodes2, self.n_output = 400, 200, 10
        self.batch_size =20
        
        self.n_features =None
        self.w1, self.w2, self.w3 = None, None, None
        self.b1, self.b2, self.b3 = None, None, None
        self.a1, self.a2, self.a3 = None, None, None
        
    def fit(self, X, y, X_val=None, y_val =None):
        
        self.n_features = X.shape[1]
        self.w1 = self._get_ini_w(self.n_features, self.n_nodes1)
        self.w2 = self._get_ini_w(self.n_nodes1, self.n_nodes2)
        self.w3 = self._get_ini_w(self.n_nodes2, self.n_output)
        
        self.b1 = np.ones((self.n_nodes1))
        self.b2 = np.ones((self.n_nodes2))
        self.b3 = np.ones((self.n_output))
        
        val_is_None = X_val is None
        train_loss_list = np.zeros((self.n_epochs))
        val_loss_list = np.zeros((self.n_epochs))
        
        for i in range(self.n_epochs):
            
            get_mini_batch = GetMiniBatch(X, y, self.batch_size)
            for mini_X_train, mini_y_train in get_mini_batch:
                self._forward_propagation(mini_X_train)
                mini_y_one_hot = self._convert_one_hot(mini_y_train)
                loss = self._get_loss(mini_y_one_hot)
                self._back_propagation(mini_X_train, mini_y_one_hot, loss)
                
            if not(val_is_None):
                self._forward_propagation(X_val)
                val_loss_list[i] = self._get_loss(self._convert_one_hot(y_val))
            train_loss_list[i] = loss
            
        if self.verbose:
            plt.plot(range(self.n_epochs), train_loss_list, color ='r', label ='train_loss')
            if not(val_is_None):
                plt.plot(range(self.n_epochs), val_loss_list, color ='b', label = 'val_loss')
            plt.xlabel('epoch')
            plt.ylabel('loss')
            plt.show()
                
    def _forward_propagation(self, X):
        
        self.a1 = X@self.w1 +self.b1
        self.z1 = self._activation(self.a1)
        self.a2 = self.z1@self.w2 +self.b2
        self.z2 = self._activation(self.a2)
        self.a3 = self.z2@self.w3 +self.b3
        self.z3 = self._softmax(self.a3)
        
        return self.z3
    
    def _back_propagation(self, X, y_one_hot, loss):
        
        a3_grad = (self.z3 - y_one_hot) / self.batch_size
        self.w3 -= self.alpha * self.z2.T@a3_grad
        self.b3 -= self.alpha * a3_grad.sum(axis =0)
        z2_grad = a3_grad@self.w3.T
        a2_grad = z2_grad * (1-self.z2**2)
        self.w2 -= self.alpha * self.z1.T@a2_grad
        self.b2 -= self.alpha * a2_grad.sum(axis =0)
        z1_grad = a2_grad@self.w2.T
        a1_grad = z1_grad * (1 - self.z1 ** 2)
        self.w1 -= self.alpha * X.T@a1_grad
        self.b1 -= self.alpha * a1_grad.sum(axis =0)
    
    def _convert_one_hot(self, y):
        return (y.reshape(-1, 1) == np.arange(self.n_output)).astype(np.float64)
    
    def _get_loss(self, y_one_hot):
        return -(y_one_hot * np.log(self.z3)).mean(axis =0).sum()
    
    def _activation(self, a):
        if self.SIGMOID == self.activation_function_flg:
            z = 1/(1+np.exp(-1*a))
        
        else:
            z = np.tanh(a)
            
        return z
    
    def _softmax(self, a):
        a = a-np.max(a, axis =-1, keepdims =True)
        return np.exp(a) / np.sum(np.exp(a), axis = -1, keepdims =True)
    
    def _get_ini_w(self, n_features, n_nodes):
        return self.sigma * np.random.randn(n_features, n_nodes)
    
    def predict(self, X):
        return self._forward_propagation(X).argmax(axis =1)

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

X_train = X_train.astype(np.float)
X_test = X_test.astype(np.float)
X_train /= 255
X_test /= 255

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)
y_train_one_hot = enc.fit_transform(y_train[:, np.newaxis])
y_test_one_hot = enc.transform(y_test[:, np.newaxis])

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)

# %%
scr_nn = ScratchSimpleNeuralNetworkClassifier(verbose = False) # インスタンス生成
scr_nn.fit(X_train, y_train) # 学習
y_pred = scr_nn.predict(X_val) # 推定
# Accuracyを計算
from sklearn.metrics import accuracy_score
print("   accuracy_score : ", accuracy_score(y_val, y_pred))
# Out:
#    accuracy_score :  0.9693333333333334

# %%
scr_nn = ScratchSimpleNeuralNetworkClassifier()
scr_nn.fit(X_train, y_train, X_val, y_val)

# %%
num = 5 # いくつ表示するか

true_false = y_pred==y_val
false_list = np.where(true_false==False)[0].astype(np.int)
if false_list.shape[0] < num:
    num = false_list.shape[0]
fig = plt.figure(figsize=(6, 6))
fig.subplots_adjust(left=0, right=0.8,  bottom=0, top=0.8, hspace=1, wspace=0.5)
for i in range(num):
    ax = fig.add_subplot(6, 6, i + 1, xticks=[], yticks=[])
    ax.set_title("{} / {}".format(y_pred[false_list[i]],y_val[false_list[i]]))
    ax.imshow(X_val.reshape(-1,28,28)[false_list[i]], cmap='gray')
